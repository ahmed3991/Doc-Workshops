# %% [markdown]
# # <center> **AI Techniques and Tools Subject**

# %% [markdown]
# <center>
#  <div style="background-color:#FFDD57; padding:10px; border-radius:6px;">
#   <h2><strong>Axis 3: Research and analysis of data driven by AI (24 hours)</strong></h2>
# </div>
# </center>

# %% [markdown]
# Axis III focuses on data acquisition, processing, and analysis using artificial intelligence (AI) tools. The objective is to master the fundamental steps of modeling and interpreting results through modern mathematical and algorithmic approaches.

# %% [markdown]
# ## 1-	Introduction to Data Science with Python (2 hours)
# - **Objective:** Establish the technical foundations of data science with Python. Explore fundamental libraries, understand data structures, and master the basic exploration and inspection commands.
# - **Tools:** <span style="color:blue">*Jupyter Notebook, Google Colab, Python 3.8+, Pandas, NumPy*</span>
# - **Tools:** <span style="color:magenta"> *Data loading CSV, Excel, JSON*</span>)

# %%
# import libraries
import pandas as pd

# %%
df_csv = pd.read_csv ( 'cars.csv' )
#df_excel = pd.read_excel ( 'data.xlsx' )
#df_json = pd.read_json ( 'data.json' )

df = df_csv

# %% [markdown]
# - **DataFrame Overview**

# %%
df.head() 	# first 5 lines
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#     price
# 0  120000
# 1  550000
# 2  215000
# 3  226000
# 4  570000

# %%
df.tail() 	# last 5 lines
# Out:
#        Unnamed: 0         car_name     brand   model  vehicle_age  km_driven  \
# 15406       19537      Hyundai i10   Hyundai     i10            9      10723
# 15407       19540    Maruti Ertiga    Maruti  Ertiga            2      18000
# 15408       19541      Skoda Rapid     Skoda   Rapid            6      67000
# 15409       19542  Mahindra XUV500  Mahindra  XUV500            5    3800000
# 15410       19543       Honda City     Honda    City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 15406      Dealer    Petrol            Manual    19.81    1086      68.05
# 15407      Dealer    Petrol            Manual    17.50    1373      91.10
# 15408      Dealer    Diesel            Manual    21.14    1498     103.52
# 15409      Dealer    Diesel            Manual    16.00    2179     140.00
# 15410      Dealer    Petrol         Automatic    18.00    1497     117.60
#
#        seats    price
# 15406      5   250000
# ...

# %%
df.sample(3) 	# 3 random lines
# Out:
#        Unnamed: 0       car_name   brand   model  vehicle_age  km_driven  \
# 15247       19333  Toyota Innova  Toyota  Innova            9      75000
# 12539       15895  Maruti Baleno  Maruti  Baleno            4      39000
# 674           861   Toyota Yaris  Toyota   Yaris            2       5000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 15247      Dealer    Diesel            Manual    12.99    2494      100.0
# 12539      Dealer    Diesel            Manual    27.39    1248       74.0
# 674    Individual    Petrol         Automatic    17.80    1496      105.5
#
#        seats    price
# 15247      7   840000
# 12539      5   695000
# 674        5  1000000

# %%
df.shape               	# dimensions (rows, columns)
# Out:
# (15411, 14)

# %%
df.columns          	# column names
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'price'],
#       dtype='object')

# %%
print(df.columns)  #same with print
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'price'],
#       dtype='object')

# %%
df.dtypes             	# types of each column
# Out:
# Unnamed: 0             int64
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# price                  int64
# dtype: object

# %%
df.info() 	# full summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  price              15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %% [markdown]
# - **Basic Statistics**

# %%
df.describe()                       # numerical statistical summary
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean    9811.857699      6.036338  5.561648e+04     19.701151   1486.057751
# std     5643.418542      3.013291  5.161855e+04      4.171265    521.106696
# min        0.000000      0.000000  1.000000e+02      4.000000    793.000000
# 25%     4906.500000      4.000000  3.000000e+04     17.000000   1197.000000
# 50%     9872.000000      6.000000  5.000000e+04     19.670000   1248.000000
# 75%    14668.500000      8.000000  7.000000e+04     22.700000   1582.000000
# max    19543.000000     29.000000  3.800000e+06     33.540000   6592.000000
#
#           max_power         seats         price
# count  15411.000000  15411.000000  1.541100e+04
# mean     100.588254      5.325482  7.749711e+05
# std       42.972979      0.807628  8.941284e+05
# min       38.400000      0.000000  4.000000e+04
# ...

# %%
df.describe().round(2)   #Round all numerical statistics in the summary to 2 decimal places for better readability
# Out:
#        Unnamed: 0  vehicle_age   km_driven   mileage    engine  max_power  \
# count    15411.00     15411.00    15411.00  15411.00  15411.00   15411.00
# mean      9811.86         6.04    55616.48     19.70   1486.06     100.59
# std       5643.42         3.01    51618.55      4.17    521.11      42.97
# min          0.00         0.00      100.00      4.00    793.00      38.40
# 25%       4906.50         4.00    30000.00     17.00   1197.00      74.00
# 50%       9872.00         6.00    50000.00     19.67   1248.00      88.50
# 75%      14668.50         8.00    70000.00     22.70   1582.00     117.30
# max      19543.00        29.00  3800000.00     33.54   6592.00     626.00
#
#           seats        price
# count  15411.00     15411.00
# mean       5.33    774971.12
# std        0.81    894128.36
# min        0.00     40000.00
# 25%        5.00    385000.00
# 50%        5.00    556000.00
# 75%        5.00    825000.00
# max        9.00  39500000.00

# %%
df['brand'].value_counts()       	# frequency of values
# Out:
# brand
# Maruti           4992
# Hyundai          2982
# Honda            1485
# Mahindra         1011
# Toyota            793
# Ford              790
# Volkswagen        620
# Renault           536
# BMW               439
# Tata              430
# Mercedes-Benz     337
# Skoda             334
# Audi              192
# Datsun            170
# Jaguar             59
# Land Rover         51
# Jeep               41
# Kia                32
# Porsche            21
# Volvo              20
# MG                 19
# Mini               17
# Nissan             11
# Lexus              10
# Isuzu               8
# Bentley             3
# Maserati            2
# ISUZU               2
# Ferrari             1
# Mercedes-AMG        1
# Rolls-Royce         1
# Force               1
# Name: count, dtype: int64

# %%
df ['brand'].nunique()            	# number of unique values
# Out:
# 32

# %% [markdown]
# - **Display configuration**

# %%
pd.set_option('display.max_columns',None) # display all columns

print(df)
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
pd.set_option('display.precision',2) # number of decimal places

print(df)
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %% [markdown]
# - **Column/Row Selection**

# %%
df ['brand'] 	# single column
# Out:
# 0          Maruti
# 1         Hyundai
# 2         Hyundai
# 3          Maruti
# 4            Ford
#            ...
# 15406     Hyundai
# 15407      Maruti
# 15408       Skoda
# 15409    Mahindra
# 15410       Honda
# Name: brand, Length: 15411, dtype: object

# %%
df [['brand' , 'price']] 	# multiple columns
# Out:
#           brand    price
# 0        Maruti   120000
# 1       Hyundai   550000
# 2       Hyundai   215000
# 3        Maruti   226000
# 4          Ford   570000
# ...         ...      ...
# 15406   Hyundai   250000
# 15407    Maruti   925000
# 15408     Skoda   425000
# 15409  Mahindra  1225000
# 15410     Honda  1200000
#
# [15411 rows x 2 columns]

# %%
df.iloc[0] 	# first line
# Out:
# Unnamed: 0                     0
# car_name             Maruti Alto
# brand                     Maruti
# model                       Alto
# vehicle_age                    9
# km_driven                 120000
# seller_type           Individual
# fuel_type                 Petrol
# transmission_type         Manual
# mileage                     19.7
# engine                       796
# max_power                   46.3
# seats                          5
# price                     120000
# Name: 0, dtype: object

# %%
df.iloc[0:5] 	# lines 0 to 4
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#     price
# 0  120000
# 1  550000
# 2  215000
# 3  226000
# 4  570000

# %%
df.loc [df['price'] > 10000] 	# conditional filtering
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %% [markdown]
# - **Creating and Deleting Columns**

# %%
df ['km_per_year'] = df['vehicle_age'] / df ['km_driven']

pd.reset_option('display.max_columns') # reset display option in default mode
print(df)
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
df.drop ('km_per_year' , axis= 1 , inplace = True)
# removes the column named 'km_per_year' from the DataFrame df by specifying
# axis=1 to indicate a column operation, and inplace=True to apply the change
# directly without reassigning the DataFrame.

print(df)
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %% [markdown]
# - **Display the row with the minimum price**

# %%
df[df['price'] == df['price'].min()]
# Out:
#       Unnamed: 0        car_name   brand    model  vehicle_age  km_driven  \
# 7607        9731  Maruti Wagon R  Maruti  Wagon R           21      80000
#
#      seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 7607  Individual    Petrol            Manual     18.9     998       67.1
#
#       seats  price
# 7607      5  40000

# %% [markdown]
# - **Sorting values**

# %%
df.sort_values (by = 'price' , ascending = False)
# Out:
#        Unnamed: 0               car_name          brand        model  \
# 3799         4845      Ferrari GTC4Lusso        Ferrari    GTC4Lusso
# 10969       13944      Rolls-Royce Ghost    Rolls-Royce        Ghost
# 1172         1508    Bentley Continental        Bentley  Continental
# 9722        12456  Mercedes-Benz S-Class  Mercedes-Benz      S-Class
# 9364        12023        Porsche Cayenne        Porsche      Cayenne
# ...           ...                    ...            ...          ...
# 7361         9413             Honda City          Honda         City
# 3787         4831            Maruti Alto         Maruti         Alto
# 12298       15593         Maruti Wagon R         Maruti      Wagon R
# 13676       17349            Maruti Alto         Maruti         Alto
# 7607         9731         Maruti Wagon R         Maruti      Wagon R
#
#        vehicle_age  km_driven seller_type fuel_type transmission_type  \
# ...

# %% [markdown]
# # <span style="color:magenta"> **🧪 Practical Workshop :** </span>
# - **Load and explore a dataset**
# - **Perform basic data analysis and filtering**
# - **Create calculated columns and sort data**

# %% [markdown]
# #### <span style="color:blue"> **Task 1️⃣ – Load and Explore the Cars Dataset**</span>

# %%
# Load the cars dataset
import pandas as pd
df = pd.read_csv("cars.csv")

# Display basic information
df.head()

# %% [markdown]
# #### 🔍 Questions:
# - *How many rows and columns does the dataset contain?*
# - *What are the column names and their data types?*
# - *Display the first 10 rows — what patterns do you notice?*
# - *What is the shape of the DataFrame?*
# - *Use .info() to check for missing values — which columns have nulls?*
# - *What is the memory usage of this DataFrame?*
# - *Display the last 5 rows using .tail() — do you see any anomalies?*
# - *Use .sample(10) to view 10 random rows — why is this useful?*

# %% [markdown]
# #### <span style="color:blue"> **Task 2️⃣ – Statistical Summary and Unique Values**</span>

# %%
# Get statistical summary
df.describe()

# Count unique brands
# df["brand"].nunique()

# %% [markdown]
# #### 🔍 Questions:
# - *What are the mean, median, and standard deviation of the price column?*
# - *How many unique car brands are in the dataset?*
# - *What is the price range (min and max)?*
# - *Which brand appears most frequently? (Hint: use .value_counts())*
# - *What percentage of cars have manual vs automatic transmission?*
# - *Find the 25th, 50th, and 75th percentiles of km_driven*
# - *How many unique fuel types are available?*
# - *What is the average vehicle age in the dataset?*

# %% [markdown]
# #### <span style="color:blue"> **Task 3️⃣ – Create Calculated Columns**</span>

# %%
# Create a new column: km_per_year
df["km_per_year"] = df["km_driven"] / df["vehicle_age"]

# Handle division by zero (if vehicle_age is 0)
df["km_per_year"] = df["km_per_year"].replace([float("inf"), -float("inf")], 0)

df.head()

# %% [markdown]
# #### 🔍 Questions:
# - *What is the average km_per_year across all vehicles?*
# - *Create a column "price_per_seat" — which cars offer the best value?*
# - *Add a boolean column "is_high_mileage" (True if km_driven > 50000)*
# - *Calculate "power_to_weight" ratio (max_power / engine)*
# - *Create "age_category": "New" (<3 years), "Used" (3-7), "Old" (>7)*
# - *Add a "fuel_efficiency_score" combining mileage and engine size*
# - *Which calculated column provides the most insight? Why?*
# - *How would you handle infinite values in km_per_year differently?*

# %% [markdown]
# #### <span style="color:blue"> **Task 4️⃣ – Filtering and Sorting Data**</span>

# %%
# Filter: Get top 10 most expensive cars
top_10_expensive = df.sort_values(by="price", ascending=False).head(10)
top_10_expensive[["car_name", "brand", "price", "vehicle_age"]]

# %% [markdown]
# #### 🔍 Questions:
# - *Which brand dominates the top 10 most expensive cars?*
# - *Filter cars with price > 1,000,000 and mileage > 15 — how many are there?*
# - *Find all Diesel cars with automatic transmission*
# - *Get the 5 newest cars (lowest vehicle_age) with highest max_power*
# - *Filter cars where seller_type is "Individual" and price < 500,000*
# - *Find cars with exactly 7 seats — which brands offer them?*
# - *Create a subset of cars manufactured by "Maruti" or "Hyundai"*
# - *Sort by multiple columns: brand (ascending), then price (descending)*

# %% [markdown]
# #### Bonus 🧠 Advanced:
# - *Load a different dataset (e.g., AAPL.csv or gapminder.csv) and perform similar analysis*
# - *Combine filtering and calculated columns: find "best value" cars (price/max_power ratio)*
# - *Use .query() method instead of boolean indexing for filtering*
# - *Create a multi-step analysis pipeline using method chaining*
# - *Export your filtered data to a new CSV file*
# - *Compare summary statistics between Petrol and Diesel cars side by side*
